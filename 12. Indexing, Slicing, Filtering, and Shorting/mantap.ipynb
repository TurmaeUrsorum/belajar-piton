# %%
import numpy as np 
import pandas as pd

# %%
nilai = pd.DataFrame([70, 80, 90],
                     index=['A', 'B', 'C'],
                     columns=['nilai'])

nilai
# Out:
#    nilai
# A     70
# B     80
# C     90

# %%
# akses sesuai nama kolom atau baris nya
nilai.loc["B", "nilai"]
# Out:
# 80

# %%
# ini pake index ngambil nya
nilai.iloc[0, 0]
# Out:
# 70

# %%
nilai["nilai"]
# Out:
# A    70
# B    80
# C    90
# Name: nilai, dtype: int64

# %%
nilai["nilai"]["B"]
# Out:
# 80

# %%
# pake data sample dari google colab
dataset = pd.read_csv("california_housing_train.csv")
dataset.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %% [markdown]
# # FIltering

# %%
# bisa pake mode true false
dataset["housing_median_age"] < 20
# yang ini return nya data true
# dataset[(dataset["housing_median_age"] < 20)]
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4        False
#          ...
# 16995    False
# 16996    False
# 16997     True
# 16998     True
# 16999    False
# Name: housing_median_age, Length: 17000, dtype: bool

# %% [markdown]
# # multiple filter

# %%
# harus pake tupple
dataset[(dataset["housing_median_age"] < 20) & (dataset["population"] < 100)]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 19       -114.67     33.92                17.0         97.0            24.0
# 113      -115.80     33.26                 2.0         96.0            18.0
# 116      -115.88     32.93                15.0        208.0            49.0
# 120      -115.94     33.38                 5.0        186.0            43.0
# 121      -115.95     33.28                12.0         99.0            25.0
# ...          ...       ...                 ...          ...             ...
# 14383    -122.11     37.31                 7.0        189.0            26.0
# 16245    -122.48     37.64                 7.0        120.0            21.0
# 16561    -122.69     39.04                 9.0        254.0            50.0
# 16643    -122.74     39.71                16.0        255.0            73.0
# 16733    -122.89     39.42                16.0        411.0           114.0
#
# ...

# %% [markdown]
# # ini bisa pake query kek sql gitu

# %%
dataset.query("housing_median_age < 20 and population < 100")
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 19       -114.67     33.92                17.0         97.0            24.0
# 113      -115.80     33.26                 2.0         96.0            18.0
# 116      -115.88     32.93                15.0        208.0            49.0
# 120      -115.94     33.38                 5.0        186.0            43.0
# 121      -115.95     33.28                12.0         99.0            25.0
# ...          ...       ...                 ...          ...             ...
# 14383    -122.11     37.31                 7.0        189.0            26.0
# 16245    -122.48     37.64                 7.0        120.0            21.0
# 16561    -122.69     39.04                 9.0        254.0            50.0
# 16643    -122.74     39.71                16.0        255.0            73.0
# 16733    -122.89     39.42                16.0        411.0           114.0
#
# ...

# %% [markdown]
# # Sort

# %%
# sorting singular
dataset.sort_values("housing_median_age", ascending=False).head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16999    -124.35     40.54                52.0       1820.0           300.0
# 14561    -122.16     38.05                52.0       1888.0           457.0
# 6551     -118.28     34.18                52.0       2602.0           418.0
# 4420     -118.03     33.99                52.0       2792.0           461.0
# 14579    -122.16     37.74                52.0        771.0           147.0
#
#        population  households  median_income  median_house_value
# 16999       806.0       270.0         3.0147             94600.0
# 14561       830.0       408.0         3.1373            185100.0
# 6551       1137.0       419.0         5.3185            358000.0
# 4420       1177.0       439.0         3.4312            243800.0
# 14579       355.0       144.0         4.1458            143400.0

# %%
# sorting mode plural
dataset.sort_values(by = ["housing_median_age", "population"], ascending=[False, True])
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1466     -117.19     32.75                52.0         25.0             5.0
# 16309    -122.50     37.79                52.0          8.0             1.0
# 11715    -121.30     37.94                52.0         24.0             6.0
# 14120    -122.06     36.96                52.0         65.0            17.0
# 11104    -121.00     37.71                52.0        102.0            23.0
# ...          ...       ...                 ...          ...             ...
# 1321     -117.16     33.57                 2.0      20391.0          3245.0
# 2372     -117.52     33.89                 2.0      17978.0          3217.0
# 11864    -121.35     38.72                 2.0      21897.0          3513.0
# 10993    -120.93     37.65                 1.0       2254.0           328.0
# 13708    -122.00     38.23                 1.0       2062.0           343.0
#
# ...

# %%
dataset.iloc[0:10]
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
# 5    -114.58     33.63                29.0       1387.0           236.0
# 6    -114.58     33.61                25.0       2907.0           680.0
# 7    -114.59     34.83                41.0        812.0           168.0
# 8    -114.59     33.61                34.0       4789.0          1175.0
# 9    -114.60     34.83                46.0       1497.0           309.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# ...
