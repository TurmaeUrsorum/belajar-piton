# %% [markdown]
# # MatplotLibb
#
# `matplotlib` adalah **library visualisasi data** di Python. Fungsinya adalah untuk **membuat grafik atau plot**, seperti grafik garis, batang, pie chart, scatter plot, histogram, dan banyak lagi.
#
# ---
#
# ## 🧠 Intinya:
#
# > `matplotlib` = "Alat gambar" untuk data di Python, mirip seperti Excel chart atau grafik di Google Sheets.
#
# ---
#
# ## 🎨 Contoh Plot Sederhana
#
# ```python
# import matplotlib.pyplot as plt
#
# x = [1, 2, 3, 4]
# y = [10, 20, 25, 30]
#
# plt.plot(x, y)
# plt.title("Contoh Grafik")
# plt.xlabel("X-Axis")
# plt.ylabel("Y-Axis")
# plt.show()
# ```
#
# ### 🔍 Output:
#
# Grafik garis naik berdasarkan data `x` dan `y`.
#
# ---
#
# ## 📦 Komponen Utama `matplotlib`
#
# | Komponen        | Kegunaan                            |
# | --------------- | ----------------------------------- |
# | `pyplot`        | Submodul utama (seperti API gambar) |
# | `plt.plot()`    | Buat garis                          |
# | `plt.bar()`     | Grafik batang                       |
# | `plt.scatter()` | Grafik titik                        |
# | `plt.hist()`    | Histogram                           |
# | `plt.pie()`     | Pie chart                           |
# | `plt.show()`    | Tampilkan grafik                    |
#
# ---
#
# ## 🔢 Contoh Lain: Bar Chart
#
# ```python
# labels = ['A', 'B', 'C']
# values = [10, 15, 7]
#
# plt.bar(labels, values)
# plt.title("Nilai Kategori")
# plt.show()
# ```
#
# ---
#
# ## 🔁 Biasanya Dipakai Bareng:
#
# * **Pandas** → untuk analisis data
# * **NumPy** → untuk data numerik
# * **Seaborn** → untuk visualisasi yang lebih "rapi" (berbasis `matplotlib`)
#
# ---
#
# ## 📌 Kapan Digunakan?
#
# * Analisis Data
# * Laporan Data
# * Dashboard
# * Exploratory Data Analysis (EDA)
# * Visualisasi hasil model Machine Learning
#
# ---
#
# Kalau kamu mau:
#
# * Contoh visualisasi data CSV
# * Bikin multi-plot
# * Bikin visualisasi interaktif (dengan `plotly`)
#
# Langsung bilang aja, nanti aku bantuin sesuai kebutuhanmu!

# %%
import matplotlib.pyplot as plt

# kita buat dulu data dummy nya 
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

plt.plot(x, y)
plt.show(
    
)

# %% [markdown]
# ## Menambahkan title
#
# syntax:
#
# matplotlib.pyplot.title(label, fontdict=None, loc=’center’, pad=None, **kwargs)

# %%
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

plt.plot(x, y)

# kita tambahkan label nya
plt.title("grafik linear ayang nisa")

plt.show()

# %%
import matplotlib.pyplot as plt

# initializing the data
x = [10, 20, 30, 40]
y = [20, 25, 35, 55]

# plotting the data
plt.plot(x, y)

# nambahin title, fontsize dan warna font nya
plt.title("grafik linear", fontsize=30, color="navy")

plt.show()

# %% [markdown]
# # menambahkan label sumbu x dan sumbu y
#
# Dalam istilah awam, label X dan label Y adalah sebutan yang diberikan masing-masing untuk sumbu X dan sumbu Y. Ini dapat ditambahkan ke grafik dengan menggunakan metode xlabel() dan ylabel().
#
# syntax:
#
# matplotlib.pyplot.xlabel(xlabel, fontdict=None, labelpad=None, **kwargs)
#
# matplotlib.pyplot.ylabel(ylabel, fontdict=None, labelpad=None, **kwargs)

# %%
import matplotlib.pyplot as plt


# initializing the data
x = [10, 20, 30, 40]
y = [20, 25, 35, 55]

# plotting the data
plt.plot(x, y)

# Adding title to the plot
plt.title("Grafik Linear", fontsize=25, color="blue")

# Adding label on the y-axis
plt.ylabel('Sumbu Y')

# Adding label on the x-axis
plt.xlabel('Sumbu X')

plt.show()

# %% [markdown]
# ## ✅ **Menetapkan Batas dan Label Centang (Ticks) di `matplotlib`**
#
# Dalam `matplotlib`, **batas** dan **centang (ticks)** digunakan untuk **mengatur skala sumbu X dan Y**, serta **memberi label** pada titik-titik tertentu agar grafik lebih jelas dibaca.
#
# ---
#
# ## 📌 1. **Batas (Limits)**
#
# Digunakan untuk **mengatur area tampilan** sumbu.
#
# ### Contoh:
#
# ```python
# plt.xlim(0, 10)  # batas sumbu X dari 0 sampai 10
# plt.ylim(0, 100) # batas sumbu Y dari 0 sampai 100
# ```
#
# ---
#
# ## 📌 2. **Centang (Ticks)**
#
# Centang/tick adalah **garis kecil dan label angka** di sepanjang sumbu.
#
# ### Contoh:
#
# ```python
# plt.xticks([0, 2, 4, 6, 8, 10])  # atur posisi centang sumbu X
# plt.yticks([0, 25, 50, 75, 100]) # atur posisi centang sumbu Y
# ```
#
# ### Bisa juga ditambah label:
#
# ```python
# plt.xticks([1, 2, 3], ['Satu', 'Dua', 'Tiga'])
# ```
#
# ---
#
# ## 🎨 Contoh Lengkap:
#
# ```python
# import matplotlib.pyplot as plt
#
# x = [1, 2, 3, 4, 5]
# y = [10, 20, 25, 30, 35]
#
# plt.plot(x, y)
#
# # Menetapkan batas
# plt.xlim(0, 6)
# plt.ylim(0, 40)
#
# # Menetapkan centang
# plt.xticks([1, 2, 3, 4, 5], ['Satu', 'Dua', 'Tiga', 'Empat', 'Lima'])
# plt.yticks([0, 10, 20, 30, 40])
#
# plt.title("Contoh Grafik dengan Batas & Ticks")
# plt.show()
# ```
#
# ---
#
# ## 🧠 Kesimpulan:
#
# | Fungsi     | Tujuan                      |
# | ---------- | --------------------------- |
# | `xlim()`   | Atur batas sumbu X          |
# | `ylim()`   | Atur batas sumbu Y          |
# | `xticks()` | Atur posisi & label sumbu X |
# | `yticks()` | Atur posisi & label sumbu Y |
#
# ---
#
# Kalau kamu mau buat grafik khusus seperti:
#
# * Ticks logaritmik
# * Rotasi label ticks
# * Hilangkan sebagian ticks
#
# Tinggal bilang aja!

# %%
import matplotlib.pyplot as plt


# initializing the data
x = [10, 20, 30, 40]
y = [20, 25, 35, 55]

# plotting the data
plt.plot(x, y)

# Adding title to the plot
plt.title("Grafik Linear", fontsize=25, color="blue")

# Adding label on the y-axis
plt.ylabel('Sumbu Y')

# Adding label on the x-axis
plt.xlabel('Sumbu X')

# setting sumbu y dari 0 ke 80 aja
plt.ylim(0, 80)

# setting the labels of x-axis
plt.xticks(x, labels=["one", "two", "three", "four"])

plt.show()

# %% [markdown]
# # Perbedaan `ticks` dan `lim`
#
# ### ✅ **Perbedaan antara `ticks` dan `lim` di Matplotlib:**
#
# #### 1. **`lim` → `xlim()` / `ylim()`**
#
# * Digunakan untuk **mengatur batas (limit)** sumbu X atau Y.
# * Contoh:
#
#   ```python
#   plt.xlim(0, 10)  # Atur batas sumbu X dari 0 sampai 10
#   plt.ylim(-1, 1)  # Atur batas sumbu Y dari -1 sampai 1
#   ```
# * Fungsinya: menentukan rentang data yang ditampilkan di grafik.
#
# #### 2. **`ticks` → `xticks()` / `yticks()`**
#
# * Digunakan untuk **mengatur posisi dan label dari ticks (garis kecil/angka)** di sepanjang sumbu.
# * Contoh:
#
#   ```python
#   plt.xticks([0, 2, 4, 6, 8, 10])  # Menampilkan ticks hanya di posisi tertentu
#   plt.yticks([-1, 0, 1])           # Menentukan posisi ticks di sumbu Y
#   ```
# * Fungsinya: mengatur di mana angka atau label muncul di sumbu.
#
# ---
#
# ### 🔍 Singkatnya:
#
# | Fungsi                  | Tujuan                          | Contoh                    |
# | ----------------------- | ------------------------------- | ------------------------- |
# | `xlim()` / `ylim()`     | Mengatur batas tampilan sumbu   | `plt.xlim(0, 100)`        |
# | `xticks()` / `yticks()` | Mengatur posisi dan label ticks | `plt.xticks([0, 25, 50])` |
#
# ---
#
# Kalau kamu punya kode tertentu yang lagi bikin bingung, kirim aja — bisa dibantu langsung juga.

# %% [markdown]
# # Legend
#
# ### ✅ Fungsi `legend()`
#
# Menampilkan **keterangan** untuk setiap elemen plot yang diberi **label**.
#
# ---
#
# ### 🔧 Cara pakainya:
#
# #### 1. **Dengan `label` saat plotting:**
#
# ```python
# import matplotlib.pyplot as plt
#
# plt.plot([1, 2, 3], [4, 5, 6], label='Data A')  # kasih label
# plt.plot([1, 2, 3], [6, 5, 4], label='Data B')
#
# plt.legend()  # tampilkan legend
# plt.show()
# ```
#
# #### 2. **Hasilnya:**
#
# Di pojok plot, akan muncul kotak legend dengan tulisan:
#
# ```
# ■ Data A
# ■ Data B
# ```
#
# ---
#
# ### 🔧 Opsi tambahan:
#
# ```python
# plt.legend(loc='upper left')       # posisi legend
# plt.legend(title='Keterangan')     # kasih judul pada legend
# ```
#
# ---
#
# ### 📌 Catatan:
#
# Legend hanya muncul kalau kamu:
#
# * Pakai `label='...'` saat plotting.
# * Atau manual lewat `plt.legend(['label1', 'label2'])` (kurang disarankan karena bisa bikin gak sinkron).
#
# ---
#
# Kalau kamu kasih kode plot-nya, bisa bantu atur legend-nya juga biar rapi.

# %%
import matplotlib.pyplot as plt


# initializing the data
x = [10, 20, 30, 40]
y = [20, 25, 35, 55]

# plotting the data
plt.plot(x, y)

# Adding title to the plot
plt.title("Grafik Linear", fontsize=25, color="blue")

# Adding label on the y-axis
plt.ylabel('Sumbu Y')

# Adding label on the x-axis
plt.xlabel('Sumbu X')

# Setting the limit of y-axis
plt.ylim(0, 80)

# setting the labels of x-axis
plt.xticks(x, labels=["one", "two", "three", "four"])

# Adding legends
plt.legend(["GFG"])

plt.show()

# %%
import matplotlib.pyplot as plt


# initializing the data
x = [10, 20, 30, 40]
y = [20, 25, 35, 55]
a = [1, 2, 3, 4]
b = [5, 6, 7, 8]

# plotting the data
plt.plot(x, y, label="data 1")
plt.plot(a, b, label="data 2")

# Adding title to the plot
plt.title("Grafik Linear", fontsize=25, color="blue")

# Adding label on the y-axis
plt.ylabel('Sumbu Y')

# Adding label on the x-axis
plt.xlabel('Sumbu X')

# Setting the limit of y-axis
plt.ylim(0, 80)

# setting the labels of x-axis
plt.xticks(x, labels=["one", "two", "three", "four"])

# Adding legends
plt.legend(title="Keterangan", loc="upper left")

plt.show()

# %% [markdown]
# Tentu! Mari kita bahas secara **terperinci** tentang **`Figure` class** di **Matplotlib**.
#
# ---
#
# ## 🧱 Apa Itu `Figure` di Matplotlib?
#
# ### 🔹 `Figure` adalah:
#
# Objek **utama** dalam Matplotlib yang merepresentasikan **keseluruhan area gambar (canvas)**, termasuk:
#
# * Sumbu-sumbu grafik (axes)
# * Judul umum (suptitle)
# * Teks global
# * Legenda global
# * Elemen visual lainnya
#
# ---
#
# ## ⚙️ Struktur Dasar Objek Visual Matplotlib
#
# ```
# Figure
# └── Axes (bisa lebih dari satu)
#      ├── XAxis & YAxis
#      ├── Title
#      ├── Grid, Ticks, Line, etc.
# ```
#
# ### Analogi:
#
# > **Figure = lembar kertas besar**
# > **Axes = kotak grafik di atas kertas**
#
# ---
#
# ## 📌 Fungsi dan Kegunaan `Figure`
#
# | Fungsi `Figure`                        | Penjelasan                                |
# | -------------------------------------- | ----------------------------------------- |
# | Menjadi **container utama**            | Semua elemen grafik ada di dalamnya       |
# | Bisa menampung **beberapa `Axes`**     | Bisa buat banyak grafik dalam satu figure |
# | Kontrol **ukuran dan resolusi** gambar | Misal: `figsize`, `dpi`, dll              |
# | Simpan ke file                         | Menggunakan `fig.savefig('nama.png')`     |
#
# ---
#
# ## 🛠️ Cara Membuat Figure
#
# ### 1. Dengan `plt.figure()` + `add_subplot()`
#
# ```python
# import matplotlib.pyplot as plt
#
# fig = plt.figure(figsize=(6, 4))  # buat figure dengan ukuran 6x4 inch
# ax = fig.add_subplot(1, 1, 1)     # tambah axes 1 baris, 1 kolom, posisi ke-1
# ax.plot([1, 2, 3], [4, 5, 6])
# fig.suptitle("Contoh Figure dan Axes")  # judul global
# plt.show()
# ```
#
# ### 2. Dengan `plt.subplots()` (cara modern dan paling umum)
#
# ```python
# fig, ax = plt.subplots(figsize=(6, 4))  # fig: figure, ax: satu axes
# ax.plot([1, 2, 3], [4, 1, 2])
# fig.suptitle("Grafik dengan plt.subplots()")
# ```
#
# ---
#
# ## 🧪 Beberapa Method Penting dari `Figure`
#
# | Method                         | Fungsi                                            |
# | ------------------------------ | ------------------------------------------------- |
# | `fig.add_subplot(...)`         | Tambahkan axes ke figure                          |
# | `fig.add_axes([x0, y0, w, h])` | Tambah axes manual (dalam unit relatif ke figure) |
# | `fig.suptitle("...")`          | Tambahkan judul global untuk figure               |
# | `fig.savefig("file.png")`      | Simpan figure ke file gambar                      |
# | `fig.set_size_inches(w, h)`    | Atur ukuran figure                                |
#
# ---
#
# ## 🎨 Contoh: Multi-Plot dengan Satu `Figure`
#
# ```python
# import matplotlib.pyplot as plt
#
# fig, axs = plt.subplots(2, 2, figsize=(8, 6))  # 2x2 axes dalam satu figure
#
# axs[0, 0].plot([1, 2], [3, 4])
# axs[0, 1].bar([1, 2], [5, 2])
# axs[1, 0].scatter([1, 2], [4, 1])
# axs[1, 1].hist([1, 1, 2, 3, 3, 3, 4])
#
# fig.suptitle("Empat Grafik dalam Satu Figure")
# plt.tight_layout()
# plt.show()
# ```
#
# ---
#
# ## 💡 Tips
#
# * Gunakan `plt.subplots()` untuk lebih rapi dan fleksibel, terutama saat membuat banyak grafik.
# * Atur ukuran figure dengan `figsize=(width, height)`.
# * Simpan hasil visualisasi dengan `fig.savefig("output.png")`.
#
# ---
#
# Kalau kamu ingin belajar bagaimana `Figure` dan `Axes` digunakan bersama untuk membuat layout custom, bisa lanjut ke contoh lanjutan seperti **gridspec** atau **subplot2grid** juga. Mau dilanjut?

# %%
import matplotlib.pyplot as plt

fig = plt.figure()

# Tambahkan axes yang posisinya di tengah (25% dari kiri & bawah) dan ukurannya 50% dari figure
ax = fig.add_axes([0.25, 0.25, 0.5, 0.5])  
ax.plot([1, 2, 3], [3, 2, 1])
ax.set_title("Plot dengan add_axes()")

plt.show()

# %%
# Python program to show pyplot module
import matplotlib.pyplot as plt
from matplotlib.figure import Figure

# initializing the data
x = [10, 20, 30, 40]
y = [20, 25, 35, 55]

# Creating a new figure with width = 7 inches
# and height = 5 inches with face color as
# green, edgecolor as red and the line width
# of the edge as 7
fig = plt.figure(figsize =(7, 5), facecolor='g',
				edgecolor='b', linewidth=7)

# Creating a new axes for the figure
ax = fig.add_axes([1, 1, 1, 1])

# Adding the data to be plotted
ax.plot(x, y)

# Adding title to the plot
plt.title("Grafik Linear", fontsize=25, color="yellow")

# Adding label on the y-axis
plt.ylabel('Sumbu Y')

# Adding label on the x-axis
plt.xlabel('Sumbu X')

# Setting the limit of y-axis
plt.ylim(0, 80)

# setting the labels of x-axis
plt.xticks(x, labels=["one", "two", "three", "four"])

# Adding legends
plt.legend(["GFG"])

plt.show()

# %% [markdown]
# ## Axes Class
#
# class Axes adalah unit paling dasar dan fleksibel untuk membuat sub-plot. Gambar tertentu mungkin berisi banyak sumbu, tetapi sumbu tertentu hanya dapat ada dalam satu gambar. Fungsi axes() membuat objek axes.
#
# syntax:
#
# axes([left, bottom, width, height])

# %%
# Python program to show pyplot module
import matplotlib.pyplot as plt
from matplotlib.figure import Figure

# initializing the data
x = [10, 20, 30, 40]
y = [20, 25, 35, 55]

fig = plt.figure(figsize = (5, 4))

# Adding the axes to the figure
ax = fig.add_axes([1, 1, 1, 1])

# plotting 1st dataset to the figure
ax1 = ax.plot(x, y)

# plotting 2nd dataset to the figure
ax2 = ax.plot(y, x)

# Setting Title
ax.set_title("Grafik Linear")

# Setting Label
ax.set_xlabel("Sumbu X")
ax.set_ylabel("Sumbu Y")

# Adding Legend
ax.legend(labels = ('garis 1', 'garis 2'))

plt.show()

# %% [markdown]
# Oke, aku jelasin ya!
#
# ---
#
# ## 🎯 Apa Itu **Multi Plot**?
#
# **Multi plot** itu artinya kamu membuat **banyak grafik (plot) dalam satu figure** atau satu gambar. Jadi, kamu bisa lihat beberapa grafik sekaligus, misalnya untuk perbandingan data atau visualisasi yang lebih kompleks.
#
# ---
#
# ## Kenapa pakai multi plot?
#
# * Supaya **bisa bandingin data** di grafik berbeda secara berdampingan.
# * Biar hasil visualisasi jadi **lebih rapi dan efisien**.
# * Memudahkan analisis kalau ada banyak variabel.
#
# ---
#
# ## 🔧 Cara buat multi plot di Matplotlib
#
# ### 1. Pakai `plt.subplot()`
#
# Contohnya bikin 2 plot dalam 1 figure:
#
# ```python
# import matplotlib.pyplot as plt
#
# plt.subplot(1, 2, 1)  # 1 baris, 2 kolom, plot ke-1
# plt.plot([1, 2, 3], [4, 5, 6])
# plt.title("Plot 1")
#
# plt.subplot(1, 2, 2)  # plot ke-2
# plt.plot([1, 2, 3], [6, 5, 4])
# plt.title("Plot 2")
#
# plt.show()
# ```
#
# ---
#
# ### 2. Pakai `plt.subplots()` (lebih fleksibel)
#
# ```python
# fig, axs = plt.subplots(2, 2)  # buat 4 plot (2 baris x 2 kolom)
#
# axs[0, 0].plot([1, 2], [3, 4])
# axs[0, 0].set_title("Plot 1")
#
# axs[0, 1].bar([1, 2], [5, 2])
# axs[0, 1].set_title("Plot 2")
#
# axs[1, 0].scatter([1, 2], [4, 1])
# axs[1, 0].set_title("Plot 3")
#
# axs[1, 1].hist([1, 1, 2, 3, 3, 3, 4])
# axs[1, 1].set_title("Plot 4")
#
# plt.tight_layout()  # supaya gak overlap
# plt.show()
# ```
#
# ---
#
# ## 🔑 Intinya:
#
# * **Multi plot** = banyak grafik dalam satu gambar.
# * Memudahkan membandingkan data.
# * Bisa diatur tata letaknya (baris, kolom, ukuran).
#
# ---
#
# Kita telah mempelajari tentang komponen dasar graf yang dapat ditambahkan sehingga dapat menyampaikan informasi lebih lanjut. Salah satu caranya adalah dengan memanggil fungsi plot berulang kali dengan kumpulan nilai yang berbeda seperti yang ditunjukkan pada contoh di atas. Sekarang mari kita lihat cara memplot banyak grafik menggunakan beberapa fungsi dan juga cara memplot subplot.

# %%
# Python program to show pyplot module
import matplotlib.pyplot as plt
from matplotlib.figure import Figure

# initializing the data
x = [10, 20, 30, 40]
y = [20, 25, 35, 55]

# Creating a new figure with width = 5 inches
# and height = 4 inches
fig = plt.figure(figsize =(5, 4))

# Creating first axes for the figure
ax1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])

# Creating second axes for the figure
ax2 = fig.add_axes([1, 0.1, 0.8, 0.8])

# Adding the data to be plotted
ax1.plot(x, y)
ax2.plot(y, x)

plt.show()

# %%
import matplotlib.pyplot as plt

plt.subplot(1, 2, 1)  # 1 baris, 2 kolom, plot ke-1
plt.plot([1, 2, 3], [4, 5, 6])
plt.title("Plot 1")

plt.subplot(1, 2, 2)  # plot ke-2
plt.plot([1, 2, 3], [6, 5, 4])
plt.title("Plot 2")

plt.show()

# %%
fig, axs = plt.subplots(2, 2)  # buat 4 plot (2 baris x 2 kolom)

axs[0, 0].plot([1, 2], [3, 4])
axs[0, 0].set_title("Plot 1")

axs[0, 1].bar([1, 2], [5, 2])
axs[0, 1].set_title("Plot 2")

axs[1, 0].scatter([1, 2], [4, 1])
axs[1, 0].set_title("Plot 3")

axs[1, 1].hist([1, 1, 2, 3, 3, 3, 4])
axs[1, 1].set_title("Plot 4")

plt.tight_layout()  # supaya gak overlap
plt.show()

# %%
import matplotlib.pyplot as plt


# initializing the data
x = [10, 20, 30, 40]
y = [20, 25, 35, 55]


# Creating figure object
plt.figure()

# adding first subplot
plt.subplot(1,2,1)
plt.plot(x, y)

# adding second subplot
plt.subplot(1,2,2)
plt.plot(y, x)

# %%
import matplotlib.pyplot as plt


# initializing the data
x = [10, 20, 30, 40]
y = [20, 25, 35, 55]


# Creating figure object
plt.figure()

# adding first subplot
plt.subplot(1,3,1)
plt.plot(x, y)

# adding second subplot
plt.subplot(1,3,2)
plt.plot(y, x)

# adding second subplot
plt.subplot(1,3,3)
plt.plot(y, x)

# %%
import matplotlib.pyplot as plt


# initializing the data
x = [10, 20, 30, 40]
y = [20, 25, 35, 55]

# Creating the figure and subplots
# according the argument passed
fig, axes = plt.subplots(1, 2)

# plotting the data in the
# 1st subplot
axes[0].plot(x, y)

# plotting the data in the 1st
# subplot only
axes[0].plot(y, x)

# plotting the data in the 2nd
# subplot only
axes[1].plot(x, y)

# %% [markdown]
# ## 🧩 Apa itu `subplot2grid`?
#
# `subplot2grid` adalah fungsi untuk **menempatkan subplot (axes) di posisi tertentu dalam grid yang fleksibel**. Dengan ini, kamu bisa mengatur layout subplot dengan ukuran dan posisi yang lebih custom dibanding `plt.subplot()` biasa.
#
# ---
#
# ## 🔍 Kenapa pakai `subplot2grid`?
#
# * Kalau kamu ingin subplot yang **tidak harus sama ukuran**, misal ada subplot yang lebih besar, yang lain lebih kecil.
# * Bisa membuat **layout grid kompleks** dengan kolom dan baris yang berbeda-beda untuk tiap subplot.
# * Lebih fleksibel daripada `plt.subplot()` yang hanya bisa satu kotak per subplot.
#
# ---
#
# ## ⚙️ Sintaks:
#
# ```python
# plt.subplot2grid(shape, loc, rowspan=1, colspan=1, fig=None)
# ```
#
# * `shape`: tuple `(rows, cols)` — ukuran grid secara keseluruhan.
# * `loc`: tuple `(row, col)` — posisi awal subplot dalam grid.
# * `rowspan`: berapa baris yang akan ditempati subplot ini (default 1).
# * `colspan`: berapa kolom yang akan ditempati subplot ini (default 1).
# * `fig`: opsional, jika ingin memasukkan subplot ke `Figure` tertentu.
#
# ---
#
# ## 📌 Contoh sederhana:
#
# ```python
# import matplotlib.pyplot as plt
#
# fig = plt.figure()
#
# # Grid 3x3, subplot di baris 0 kolom 0 (posisi kiri atas)
# ax1 = plt.subplot2grid((3, 3), (0, 0), colspan=3)
# ax1.plot([1, 2, 3], [1, 4, 9])
# ax1.set_title("Plot besar di atas")
#
# # Subplot di baris 1 kolom 0, mengambil 1 kolom dan 2 baris
# ax2 = plt.subplot2grid((3, 3), (1, 0), rowspan=2)
# ax2.bar([1, 2], [3, 5])
# ax2.set_title("Plot kiri bawah")
#
# # Subplot di baris 1 kolom 1
# ax3 = plt.subplot2grid((3, 3), (1, 1))
# ax3.scatter([1, 2, 3], [2, 4, 6])
# ax3.set_title("Plot kanan tengah")
#
# # Subplot di baris 1 kolom 2
# ax4 = plt.subplot2grid((3, 3), (1, 2))
# ax4.hist([1, 2, 2, 3, 3, 3])
# ax4.set_title("Plot kanan bawah")
#
# plt.tight_layout()
# plt.show()
# ```
#
# ---
#
# ## 🔑 Kelebihan `subplot2grid`:
#
# * Layout **lebih fleksibel dan dinamis**.
# * Bisa buat subplot yang **besar dan kecil dalam satu figure**.
# * Posisi subplot lebih presisi daripada `plt.subplot()`.
#
# ---

# %%
import matplotlib.pyplot as plt

fig = plt.figure()

# Grid 3x3, subplot di baris 0 kolom 0 (posisi kiri atas)
ax1 = plt.subplot2grid((3, 3), (0, 0), colspan=3)
ax1.plot([1, 2, 3], [1, 4, 9])
ax1.set_title("Plot besar di atas")

# Subplot di baris 1 kolom 0, mengambil 1 kolom dan 2 baris
ax2 = plt.subplot2grid((3, 3), (1, 0), rowspan=2)
ax2.bar([1, 2], [3, 5])
ax2.set_title("Plot kiri bawah")

# Subplot di baris 1 kolom 1
ax3 = plt.subplot2grid((3, 3), (1, 1))
ax3.scatter([1, 2, 3], [2, 4, 6])
ax3.set_title("Plot kanan tengah")

# Subplot di baris 1 kolom 2
ax4 = plt.subplot2grid((3, 3), (1, 2))
ax4.hist([1, 2, 2, 3, 3, 3])
ax4.set_title("Plot kanan bawah")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# initializing the data
x = [10, 20, 30, 40]
y = [20, 25, 35, 55]

# adding the subplots
axes1 = plt.subplot2grid (
(7, 1), (0, 0), rowspan = 2, colspan = 1)

axes2 = plt.subplot2grid (
(7, 1), (2, 0), rowspan = 2, colspan = 1)

# plotting the data
axes1.plot(x, y)
axes2.plot(y, x)
